# %%
from ultralytics import YOLO
"E:\images (4).jpg"

# %%
model = YOLO("yolov8s.pt")

# %%
model.train(data ="/mnt/e/pothole_dataset/data.yaml",epochs = 50,imgsz = 640,batch=-1)
# Out:
# New https://pypi.org/project/ultralytics/8.4.96 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.95 🚀 Python-3.12.3 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# ...

# %%
print(model.info())
# Out:
# Model summary: 130 layers, 11,135,987 parameters, 0 gradients, 28.6 GFLOPs
# (130, 11135987, 0, 28.6469632)

# %%
res = model.predict("/mnt/e/images (9).jpg")
# Out:
# image 1/1 /mnt/e/images (9).jpg: 640x448 1 pothole, 121.2ms
# Speed: 3.5ms preprocess, 121.2ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 448)

# %%
res[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=269x403>
